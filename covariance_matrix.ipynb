# %% [markdown]
# ## Librairies used :

# %%
import pandas as pd
import numpy as np
import polars as pl
import json
import tarfile
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from typing import Tuple
import os
import itertools
from numpy import linalg as LA
import numpy as np
from numpy.linalg import eig
import networkx as nx
from sklearn.preprocessing import MinMaxScaler
import community
from matplotlib.patches import Patch
from clustering_script import *

# %% [markdown]
# ## Compute covariance matrices

# %% [markdown]
# **Computing the covariance matrices with hayashi_yoshida estimator using the functions in utils on the dates with highest responses**

# %% [markdown]
# ### Compute covariance matrix for demo

# %%
compute_covariance_matrices("processed/final_yearly/",
                            ["2010-05-06-14:45"],
                            "output_cov_matrices")
# Out:
# ['2010-05-06-14:45']
# Processing date: 2010-05-06 with start time: 14:45
# Covariance matrices saved for all dates in output_cov_matrices.

# %% [markdown]
# ### Compute covariance matrix for all dates

# %%
highest_responses_strings = ['2010-01-27-14:00', '2010-02-03-13:00', '2010-03-08-12:30', '2010-04-05-10:00',
 '2010-06-11-13:15', '2010-07-23-12:45', '2010-08-20-12:45', '2010-09-23-14:30',
 '2010-10-28-13:00', '2010-11-26-13:15', '2010-12-31-12:00']

compute_covariance_matrices("data_clean",
                            highest_responses_strings,
                            "output_cov_matrices3")

# %% [markdown]
# ## Create and plot the different clusters for each period and each date

# %% [markdown]
# **Differents steps after creating the covariances files :**
#
# - Iterate over each file and each date
# - Read the corresponding covariance matrix
# - Clip the matrix using the eigen_value method discussed in class
# - Adjust with normalization the matrix to perform Louvain clustering
# - Save the resulting clusters

# %%
def main():

    # Define the periods and their corresponding file paths
    periods_files = {
        'before': 'output_cov_matrices/before.parquet',
        'during': 'output_cov_matrices/during.parquet',
        'after': 'output_cov_matrices/after.parquet'
    }

    # Create a directory to save all plots
    output_dir = 'cluster_plots_crash'
    os.makedirs(output_dir, exist_ok=True)

    # Create separate files for saving clusters for each period
    cluster_output_files = {
        period: os.path.join(output_dir, f'{period}_clusters.jsonl')
        for period in periods_files
    }

    # Ensure the cluster files are empty before appending new results
    for cluster_file in cluster_output_files.values():
        open(cluster_file, 'w').close()

    # Iterate over each period and its corresponding file
    for period, file_path in periods_files.items():
        print(f'\nProcessing Period: {period.capitalize()} | File: {file_path}')

        # Load all covariance matrices for the period
        try:
            cov_matrices_dict = load_and_reshape_covariance(file_path)
        except Exception as e:
            print(f'Error loading file {file_path}: {e}')
            continue

        # Iterate over each date and its covariance matrix
        for date, cov_matrix in cov_matrices_dict.items():
            print(f'  Processing Date: {date}')

            try:
                # Step 1: Apply eigenvalue clipping
                clipped_cov_matrix = eigenvalue_clipping(cov_matrix)
                # Step 2: Fill diagonal with zeros
                np.fill_diagonal(clipped_cov_matrix, 0)
                clipped_cov_matrix = np.asarray(clipped_cov_matrix)
                # Step 3: Normalize the covariance matrix
                scaler = MinMaxScaler()
                adj_matrix = scaler.fit_transform(clipped_cov_matrix)
                # Step 4: Perform Louvain clustering
                partition_optimal = perform_louvain_clustering(adj_matrix)

                clusters_optimal = {}
                for node, cluster_id in partition_optimal.items():
                    # Ensure node index is within the range of asset_names
                    if node < len(asset_names):
                        asset_name = asset_names[node]
                    else:
                        asset_name = f'Asset_{node}'  # Placeholder for undefined assets
                    clusters_optimal.setdefault(cluster_id, []).append(asset_name)

                # Output the optimal clustering results
                print(f'    Optimal Clustering: {clusters_optimal}')

                # Step 5: Save the clusters to the corresponding file
                cluster_data = {
                    'date': date,
                    'clusters': clusters_optimal
                }
                with open(cluster_output_files[period], 'a') as f:
                    f.write(json.dumps(cluster_data) + '\n')

                # Step 6: Process the clusters to count domains
                cluster_domains = {}
                for cluster_id, assets in clusters_optimal.items():
                    # Initialize domain count for the cluster
                    domain_count = {domain: 0 for domain in domain_colors.keys()}
                    for asset in assets:
                        domain = asset_to_domain.get(asset, 'Unknown')
                        domain_count[domain] += 1
                    cluster_domains[cluster_id] = domain_count

                # Step 7: Define the save path for the plot
                # Create a directory for the period if it doesn't exist
                period_dir = os.path.join(output_dir, period)
                os.makedirs(period_dir, exist_ok=True)

                # Define the filename based on the date
                save_filename = f'{period}_{date}.png'
                save_path = os.path.join(period_dir, save_filename)

                # Step 8: Plot and save the cluster domains
                plot_cluster_domains(
                    cluster_domains=cluster_domains,
                    clusters_optimal=clusters_optimal,
                    domain_colors=domain_colors,
                    period=period,
                    date=date,
                    save_path=save_path
                )

                print(f'    Plot saved to: {save_path}')

            except Exception as e:
                print(f'    Error processing date {date}: {e}')
                continue

    print('\nAll clustering and plotting completed.')

if __name__ == "__main__":
    main()
# Out:
# Processing Period: Before | File: output_cov_matrices/before.parquet
#   Processing Date: 2010-05-06
#     Optimal Clustering: {4: ['AAPL', 'AMGN', 'BA', 'CAT', 'CSCO', 'MMM', 'TRV'], 0: ['AXP', 'HD', 'WMT'], 2: ['CVX', 'MRK', 'VZ'], 5: ['DOW', 'KO', 'UTX', 'XOM'], 3: ['IBM', 'PG', 'V'], 1: ['INTC', 'JPM']}
#     Plot saved to: cluster_plots_crash\before\before_2010-05-06.png
#
# Processing Period: During | File: output_cov_matrices/during.parquet
#   Processing Date: 2010-05-06
#     Optimal Clustering: {5: ['AAPL', 'HD', 'JPM'], 1: ['AMGN', 'DOW', 'IBM', 'KO'], 2: ['AXP', 'BA', 'MRK'], 0: ['CAT', 'V', 'VZ'], 3: ['CSCO', 'WMT', 'XOM'], 6: ['CVX', 'MMM', 'TRV'], 4: ['INTC', 'PG', 'UTX']}
#     Plot saved to: cluster_plots_crash\during\during_2010-05-06.png
#
# Processing Period: After | File: output_cov_matrices/after.parquet
#   Processing Date: 2010-05-06
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CSCO', 'IBM', 'INTC', 'KO'], 0: ['CVX', 'JPM', 'MMM', 'MRK', 'PG', 'TRV', 'V', 'VZ'], 2: ['DOW', 'HD', 'UTX', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_crash\after\after_2010-05-06.png
#
# All clustering and plotting completed.

# %%
def main():

    # Define the periods and their corresponding file paths
    periods_files = {
        'before': 'output_cov_matrices2/before.parquet',
        'during': 'output_cov_matrices2/during.parquet',
        'after': 'output_cov_matrices2/after.parquet'
    }

    # Create a directory to save all plots
    output_dir = 'cluster_plots_all'
    os.makedirs(output_dir, exist_ok=True)

    # Create separate files for saving clusters for each period
    cluster_output_files = {
        period: os.path.join(output_dir, f'{period}_clusters.jsonl')
        for period in periods_files
    }

    # Ensure the cluster files are empty before appending new results
    for cluster_file in cluster_output_files.values():
        open(cluster_file, 'w').close()

    # Iterate over each period and its corresponding file
    for period, file_path in periods_files.items():
        print(f'\nProcessing Period: {period.capitalize()} | File: {file_path}')

        # Load all covariance matrices for the period
        try:
            cov_matrices_dict = load_and_reshape_covariance(file_path)
        except Exception as e:
            print(f'Error loading file {file_path}: {e}')
            continue

        # Iterate over each date and its covariance matrix
        for date, cov_matrix in cov_matrices_dict.items():
            print(f'  Processing Date: {date}')

            try:
                # Step 1: Apply eigenvalue clipping
                clipped_cov_matrix = eigenvalue_clipping(cov_matrix)
                # Step 2: Fill diagonal with zeros
                np.fill_diagonal(clipped_cov_matrix, 0)
                clipped_cov_matrix = np.asarray(clipped_cov_matrix)
                # Step 3: Normalize the covariance matrix
                scaler = MinMaxScaler()
                adj_matrix = scaler.fit_transform(clipped_cov_matrix)
                # Step 4: Perform Louvain clustering
                partition_optimal = perform_louvain_clustering(adj_matrix)

                clusters_optimal = {}
                for node, cluster_id in partition_optimal.items():
                    # Ensure node index is within the range of asset_names
                    if node < len(asset_names):
                        asset_name = asset_names[node]
                    else:
                        asset_name = f'Asset_{node}'  # Placeholder for undefined assets
                    clusters_optimal.setdefault(cluster_id, []).append(asset_name)

                # Output the optimal clustering results
                print(f'    Optimal Clustering: {clusters_optimal}')

                # Step 5: Save the clusters to the corresponding file
                cluster_data = {
                    'date': date,
                    'clusters': clusters_optimal
                }
                with open(cluster_output_files[period], 'a') as f:
                    f.write(json.dumps(cluster_data) + '\n')

                # Step 6: Process the clusters to count domains
                cluster_domains = {}
                for cluster_id, assets in clusters_optimal.items():
                    # Initialize domain count for the cluster
                    domain_count = {domain: 0 for domain in domain_colors.keys()}
                    for asset in assets:
                        domain = asset_to_domain.get(asset, 'Unknown')
                        domain_count[domain] += 1
                    cluster_domains[cluster_id] = domain_count

                # Step 7: Define the save path for the plot
                # Create a directory for the period if it doesn't exist
                period_dir = os.path.join(output_dir, period)
                os.makedirs(period_dir, exist_ok=True)

                # Define the filename based on the date
                save_filename = f'{period}_{date}.png'
                save_path = os.path.join(period_dir, save_filename)

                # Step 8: Plot and save the cluster domains
                plot_cluster_domains(
                    cluster_domains=cluster_domains,
                    clusters_optimal=clusters_optimal,
                    domain_colors=domain_colors,
                    period=period,
                    date=date,
                    save_path=save_path
                )

                print(f'    Plot saved to: {save_path}')

            except Exception as e:
                print(f'    Error processing date {date}: {e}')
                continue

    print('\nAll clustering and plotting completed.')

if __name__ == "__main__":
    main()
# Out:
# Processing Period: Before | File: output_cov_matrices2/before.parquet
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL', 'IBM'], 1: ['AMGN', 'AXP', 'CSCO', 'INTC'], 3: ['BA', 'VZ'], 7: ['CAT', 'UTX'], 6: ['CVX', 'MRK'], 4: ['DOW', 'KO'], 8: ['HD', 'V'], 2: ['JPM', 'MMM'], 5: ['PG', 'TRV', 'WMT'], 9: ['XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-11-26.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'CAT', 'TRV'], 3: ['AMGN', 'BA', 'CVX', 'MRK', 'PG'], 2: ['AXP', 'V'], 4: ['CSCO', 'IBM'], 1: ['DOW', 'HD'], 6: ['INTC', 'MMM'], 7: ['JPM', 'KO'], 5: ['UTX', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-01-27.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'BA', 'IBM', 'JPM', 'MMM', 'PG', 'TRV'], 2: ['CAT'], 1: ['CSCO', 'HD', 'INTC', 'MRK', 'UTX', 'V', 'VZ', 'WMT', 'XOM'], 3: ['CVX', 'DOW', 'KO']}
#     Plot saved to: cluster_plots_all\before\before_2010-04-05.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {0: ['AAPL', 'UTX'], 1: ['AMGN', 'DOW'], 2: ['AXP', 'XOM'], 3: ['BA', 'CAT', 'INTC', 'KO'], 5: ['CSCO', 'MMM', 'VZ', 'WMT'], 8: ['CVX', 'TRV'], 6: ['HD', 'V'], 7: ['IBM', 'PG'], 4: ['JPM', 'MRK']}
#     Plot saved to: cluster_plots_all\before\before_2010-08-20.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {0: ['AAPL', 'TRV', 'WMT'], 1: ['AMGN', 'BA', 'MRK'], 2: ['AXP', 'HD', 'JPM', 'KO'], 3: ['CAT', 'PG'], 4: ['CSCO', 'IBM', 'MMM', 'V', 'XOM'], 5: ['CVX', 'UTX', 'VZ'], 6: ['DOW', 'INTC']}
#     Plot saved to: cluster_plots_all\before\before_2010-02-03.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {1: ['AAPL', 'MMM'], 2: ['AMGN', 'CSCO'], 6: ['AXP', 'CVX'], 3: ['BA', 'DOW', 'HD', 'UTX'], 4: ['CAT', 'JPM'], 7: ['IBM', 'PG'], 0: ['INTC', 'MRK'], 8: ['KO', 'V'], 5: ['TRV', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-06-11.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'BA', 'CSCO'], 2: ['AMGN', 'CAT', 'CVX', 'HD', 'IBM', 'INTC', 'JPM', 'KO', 'MMM', 'PG', 'TRV'], 1: ['DOW', 'MRK', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-07-23.png
#   Processing Date: 2010-09-23
#     Optimal Clustering: {0: ['AAPL', 'HD', 'JPM'], 3: ['AMGN', 'AXP', 'UTX'], 1: ['BA', 'KO', 'XOM'], 2: ['CAT', 'INTC', 'MMM'], 5: ['CSCO', 'PG', 'TRV'], 6: ['CVX', 'IBM', 'WMT'], 7: ['DOW', 'V', 'VZ'], 4: ['MRK']}
#     Plot saved to: cluster_plots_all\before\before_2010-09-23.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'CAT', 'DOW', 'HD', 'INTC', 'JPM'], 1: ['AXP', 'CVX', 'KO', 'MRK'], 2: ['BA', 'MMM', 'PG', 'TRV', 'UTX', 'VZ', 'WMT'], 3: ['CSCO', 'IBM', 'V', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-03-08.png
#   Processing Date: 2010-12-31
#     Optimal Clustering: {4: ['AAPL', 'AMGN', 'MRK'], 2: ['AXP', 'CSCO', 'KO'], 3: ['BA', 'IBM', 'JPM'], 1: ['CAT', 'DOW', 'INTC'], 6: ['CVX', 'V', 'WMT'], 0: ['HD', 'MMM', 'PG'], 5: ['TRV', 'UTX', 'VZ', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-12-31.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'V'], 0: ['CAT', 'JPM'], 3: ['CSCO', 'CVX'], 4: ['DOW', 'MMM'], 5: ['HD', 'IBM'], 6: ['INTC', 'KO'], 7: ['MRK', 'UTX'], 8: ['PG', 'TRV'], 2: ['VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\before\before_2010-10-28.png
#
# Processing Period: During | File: output_cov_matrices2/during.parquet
#   Processing Date: 2010-09-23
#     Optimal Clustering: {0: ['AAPL', 'MRK', 'PG', 'TRV', 'UTX', 'V', 'WMT', 'XOM'], 1: ['AMGN', 'BA', 'CVX', 'INTC', 'KO', 'MMM', 'VZ'], 2: ['AXP', 'CAT', 'CSCO', 'DOW', 'HD', 'IBM', 'JPM']}
#     Plot saved to: cluster_plots_all\during\during_2010-09-23.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {7: ['AAPL', 'BA', 'CVX', 'MMM', 'PG'], 1: ['AMGN', 'JPM', 'WMT'], 0: ['AXP', 'HD'], 3: ['CAT', 'V'], 4: ['CSCO', 'KO', 'TRV'], 5: ['DOW', 'VZ', 'XOM'], 6: ['IBM', 'INTC'], 2: ['MRK', 'UTX']}
#     Plot saved to: cluster_plots_all\during\during_2010-08-20.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'CAT', 'UTX'], 1: ['AMGN', 'TRV', 'VZ'], 2: ['AXP', 'HD', 'XOM'], 6: ['BA', 'DOW', 'PG', 'V'], 4: ['CSCO', 'IBM', 'JPM'], 5: ['CVX', 'INTC', 'MRK'], 3: ['KO', 'MMM', 'WMT']}
#     Plot saved to: cluster_plots_all\during\during_2010-01-27.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {3: ['AAPL', 'BA', 'IBM', 'INTC', 'JPM', 'MMM', 'WMT'], 1: ['AMGN', 'CAT'], 2: ['AXP', 'CSCO', 'CVX', 'KO', 'V'], 0: ['DOW', 'HD', 'MRK', 'PG', 'TRV', 'UTX', 'VZ', 'XOM']}
#     Plot saved to: cluster_plots_all\during\during_2010-10-28.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'CSCO', 'DOW', 'HD', 'IBM', 'KO', 'MMM', 'UTX'], 1: ['AMGN', 'CVX', 'INTC', 'JPM', 'MRK', 'TRV', 'V', 'WMT', 'XOM'], 3: ['BA', 'PG'], 2: ['CAT', 'VZ']}
#     Plot saved to: cluster_plots_all\during\during_2010-06-11.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DOW', 'HD', 'INTC'], 2: ['IBM', 'MRK', 'PG', 'UTX', 'V', 'WMT'], 3: ['JPM', 'XOM'], 4: ['KO', 'VZ'], 0: ['MMM', 'TRV']}
#     Plot saved to: cluster_plots_all\during\during_2010-04-05.png
#   Processing Date: 2010-12-31
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'INTC', 'JPM', 'KO', 'MMM', 'MRK', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM'], 0: ['CSCO', 'DOW', 'HD', 'IBM']}
#     Plot saved to: cluster_plots_all\during\during_2010-12-31.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'CAT', 'DOW', 'KO', 'MMM', 'TRV', 'V', 'WMT'], 1: ['AXP', 'BA', 'CSCO', 'CVX', 'IBM', 'INTC', 'JPM', 'MRK', 'PG', 'UTX'], 2: ['HD'], 0: ['VZ', 'XOM']}
#     Plot saved to: cluster_plots_all\during\during_2010-07-23.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'CAT', 'HD', 'UTX', 'V', 'WMT', 'XOM'], 1: ['AMGN', 'CSCO', 'CVX', 'DOW', 'MRK', 'TRV'], 2: ['BA', 'MMM'], 5: ['IBM', 'INTC'], 3: ['JPM', 'VZ'], 4: ['KO', 'PG']}
#     Plot saved to: cluster_plots_all\during\during_2010-02-03.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots_all\during\during_2010-03-08.png
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots_all\during\during_2010-11-26.png
#
# Processing Period: After | File: output_cov_matrices2/after.parquet
#   Processing Date: 2010-12-31
#     Optimal Clustering: {5: ['AAPL', 'AXP', 'BA', 'DOW', 'IBM', 'MMM', 'MRK', 'VZ'], 0: ['AMGN', 'INTC', 'TRV'], 2: ['CAT', 'PG', 'UTX', 'V', 'WMT', 'XOM'], 3: ['CSCO'], 4: ['CVX', 'JPM', 'KO'], 1: ['HD']}
#     Plot saved to: cluster_plots_all\after\after_2010-12-31.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {0: ['AAPL', 'JPM'], 1: ['AMGN', 'MMM'], 2: ['AXP', 'BA', 'DOW', 'V'], 4: ['CAT', 'XOM'], 5: ['CSCO', 'TRV'], 6: ['CVX', 'WMT'], 7: ['HD', 'MRK', 'PG', 'VZ'], 8: ['IBM', 'INTC'], 3: ['KO', 'UTX']}
#     Plot saved to: cluster_plots_all\after\after_2010-02-03.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {5: ['AAPL', 'CSCO'], 2: ['AMGN', 'JPM'], 3: ['AXP', 'MRK'], 4: ['BA', 'MMM', 'PG'], 0: ['CAT', 'HD', 'UTX', 'WMT', 'XOM'], 6: ['CVX', 'KO', 'V'], 7: ['DOW', 'TRV', 'VZ'], 1: ['IBM', 'INTC']}
#     Plot saved to: cluster_plots_all\after\after_2010-08-20.png
#   Processing Date: 2010-09-23
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'CAT', 'CVX', 'HD', 'IBM', 'INTC', 'MMM'], 2: ['BA', 'CSCO', 'JPM', 'MRK'], 1: ['DOW', 'KO', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\after\after_2010-09-23.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'IBM', 'UTX'], 1: ['CSCO', 'DOW'], 3: ['CVX', 'V', 'VZ'], 4: ['HD', 'INTC', 'KO', 'MMM', 'MRK', 'PG', 'TRV', 'XOM'], 2: ['JPM', 'WMT']}
#     Plot saved to: cluster_plots_all\after\after_2010-07-23.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'CAT', 'CSCO', 'CVX', 'HD', 'JPM', 'KO', 'WMT', 'XOM'], 1: ['AXP', 'MMM'], 0: ['BA', 'MRK', 'PG'], 2: ['DOW', 'IBM', 'INTC', 'TRV', 'UTX', 'V', 'VZ']}
#     Plot saved to: cluster_plots_all\after\after_2010-10-28.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {6: ['AAPL', 'AMGN', 'CSCO', 'CVX', 'PG'], 2: ['AXP', 'IBM'], 1: ['BA', 'INTC'], 4: ['CAT', 'DOW'], 7: ['HD', 'WMT'], 3: ['JPM', 'KO', 'MMM'], 5: ['MRK', 'TRV', 'UTX', 'V', 'VZ'], 0: ['XOM']}
#     Plot saved to: cluster_plots_all\after\after_2010-04-05.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'CSCO', 'V'], 1: ['AMGN', 'UTX', 'XOM'], 2: ['AXP', 'BA', 'CVX', 'PG'], 3: ['CAT', 'IBM', 'WMT'], 5: ['DOW', 'INTC', 'VZ'], 6: ['HD', 'KO', 'MRK'], 4: ['JPM', 'MMM', 'TRV']}
#     Plot saved to: cluster_plots_all\after\after_2010-01-27.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'INTC', 'MMM', 'PG'], 1: ['AXP', 'CAT', 'KO'], 2: ['BA', 'CVX', 'IBM'], 3: ['CSCO', 'DOW', 'HD'], 4: ['JPM', 'UTX'], 5: ['MRK', 'TRV', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots_all\after\after_2010-03-08.png
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots_all\after\after_2010-11-26.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'CAT', 'CVX', 'DOW', 'HD', 'IBM', 'INTC', 'MRK', 'TRV', 'XOM'], 1: ['BA', 'MMM'], 3: ['CSCO', 'PG'], 2: ['JPM', 'KO', 'UTX', 'V', 'VZ', 'WMT']}
#     Plot saved to: cluster_plots_all\after\after_2010-06-11.png
#
# All clustering and plotting completed.

# %%
def process_covariance_matrices(cov_matrix_path, output_folder):
    """
    Processes covariance matrices, applies clustering, and generates plots.
    
    Parameters:
        cov_matrix_path (str): Path to the directory containing covariance matrix files.
        output_folder (str): Path to the output directory for saving results.
    """

    # Define the periods and their corresponding file paths
    periods_files = {
        'before': f'{cov_matrix_path}/before.parquet',
        'during': f'{cov_matrix_path}/during.parquet',
        'after': f'{cov_matrix_path}/after.parquet'
    }

    # Create a directory to save all plots
    os.makedirs(output_folder, exist_ok=True)

    # Create separate files for saving clusters for each period
    cluster_output_files = {
        period: os.path.join(output_folder, f'{period}_clusters.jsonl')
        for period in periods_files
    }

    # Ensure the cluster files are empty before appending new results
    for cluster_file in cluster_output_files.values():
        open(cluster_file, 'w').close()

    # Iterate over each period and its corresponding file
    for period, file_path in periods_files.items():
        print(f'\nProcessing Period: {period.capitalize()} | File: {file_path}')

        # Load all covariance matrices for the period
        try:
            cov_matrices_dict = load_and_reshape_covariance(file_path)
        except Exception as e:
            print(f'Error loading file {file_path}: {e}')
            continue

        # Iterate over each date and its covariance matrix
        for date, cov_matrix in cov_matrices_dict.items():
            print(f'  Processing Date: {date}')

            try:
                # Step 1: Apply eigenvalue clipping
                clipped_cov_matrix = eigenvalue_clipping(cov_matrix)
                # Step 2: Fill diagonal with zeros
                np.fill_diagonal(clipped_cov_matrix, 0)
                clipped_cov_matrix = np.asarray(clipped_cov_matrix)
                # Step 3: Normalize the covariance matrix
                scaler = MinMaxScaler()
                adj_matrix = scaler.fit_transform(clipped_cov_matrix)
                # Step 4: Perform Louvain clustering
                partition_optimal = perform_louvain_clustering(adj_matrix)

                clusters_optimal = {}
                for node, cluster_id in partition_optimal.items():
                    # Ensure node index is within the range of asset_names
                    if node < len(asset_names):
                        asset_name = asset_names[node]
                    else:
                        asset_name = f'Asset_{node}'  # Placeholder for undefined assets
                    clusters_optimal.setdefault(cluster_id, []).append(asset_name)

                # Output the optimal clustering results
                print(f'    Optimal Clustering: {clusters_optimal}')

                # Step 5: Save the clusters to the corresponding file
                cluster_data = {
                    'date': date,
                    'clusters': clusters_optimal
                }
                with open(cluster_output_files[period], 'a') as f:
                    f.write(json.dumps(cluster_data) + '\n')

                # Step 6: Process the clusters to count domains
                cluster_domains = {}
                for cluster_id, assets in clusters_optimal.items():
                    # Initialize domain count for the cluster
                    domain_count = {domain: 0 for domain in domain_colors.keys()}
                    for asset in assets:
                        domain = asset_to_domain.get(asset, 'Unknown')
                        domain_count[domain] += 1
                    cluster_domains[cluster_id] = domain_count

                # Step 7: Define the save path for the plot
                # Create a directory for the period if it doesn't exist
                period_dir = os.path.join(output_folder, period)
                os.makedirs(period_dir, exist_ok=True)

                # Define the filename based on the date
                save_filename = f'{period}_{date}.png'
                save_path = os.path.join(period_dir, save_filename)

                # Step 8: Plot and save the cluster domains
                plot_cluster_domains(
                    cluster_domains=cluster_domains,
                    clusters_optimal=clusters_optimal,
                    domain_colors=domain_colors,
                    period=period,
                    date=date,
                    save_path=save_path
                )

                print(f'    Plot saved to: {save_path}')

            except Exception as e:
                print(f'    Error processing date {date}: {e}')
                continue

    print('\nAll clustering and plotting completed.')

process_covariance_matrices('output_cov_matrices2', "test")
# Out:
# Processing Period: Before | File: output_cov_matrices2/before.parquet
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'CSCO', 'INTC'], 1: ['AXP', 'IBM'], 3: ['BA', 'JPM'], 7: ['CAT', 'V'], 6: ['CVX', 'UTX'], 8: ['DOW', 'HD'], 9: ['KO', 'MRK'], 2: ['MMM', 'VZ'], 5: ['PG', 'TRV', 'WMT'], 4: ['XOM']}
#     Plot saved to: test\before\before_2010-11-26.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'JPM', 'TRV'], 4: ['AMGN', 'CAT', 'CVX', 'IBM', 'PG'], 2: ['AXP', 'HD'], 3: ['BA', 'MMM'], 1: ['CSCO', 'V'], 6: ['DOW', 'KO'], 7: ['INTC', 'MRK'], 5: ['UTX', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: test\before\before_2010-01-27.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {0: ['AAPL', 'BA', 'IBM', 'XOM'], 2: ['AMGN', 'AXP', 'CAT', 'CSCO', 'DOW', 'HD', 'JPM', 'KO', 'MMM', 'PG', 'TRV'], 1: ['CVX', 'INTC', 'MRK', 'UTX', 'V', 'VZ', 'WMT']}
#     Plot saved to: test\before\before_2010-04-05.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {0: ['AAPL', 'UTX'], 1: ['AMGN', 'INTC'], 2: ['AXP', 'XOM'], 3: ['BA', 'V'], 4: ['CAT', 'CVX', 'HD', 'KO'], 5: ['CSCO', 'JPM'], 7: ['DOW', 'IBM'], 8: ['MMM', 'MRK', 'VZ', 'WMT'], 6: ['PG', 'TRV']}
#     Plot saved to: test\before\before_2010-08-20.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {0: ['AAPL', 'IBM', 'TRV'], 1: ['AMGN', 'CVX', 'UTX'], 2: ['AXP', 'DOW', 'MMM', 'MRK', 'PG'], 3: ['BA', 'JPM', 'KO', 'WMT'], 4: ['CAT', 'INTC'], 5: ['CSCO', 'XOM'], 6: ['HD', 'V', 'VZ']}
#     Plot saved to: test\before\before_2010-02-03.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {0: ['AAPL', 'INTC'], 1: ['AMGN', 'IBM'], 2: ['AXP', 'V'], 7: ['BA', 'DOW', 'JPM', 'UTX'], 4: ['CAT', 'MRK'], 5: ['CSCO', 'PG'], 6: ['CVX', 'KO'], 8: ['HD', 'MMM'], 3: ['TRV', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: test\before\before_2010-06-11.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {1: ['AAPL', 'AXP', 'BA', 'CSCO'], 0: ['AMGN', 'CAT', 'CVX', 'HD', 'IBM', 'INTC', 'JPM', 'KO', 'MMM', 'PG', 'TRV'], 2: ['DOW', 'MRK', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: test\before\before_2010-07-23.png
#   Processing Date: 2010-09-23
#     Optimal Clustering: {4: ['AAPL', 'CAT', 'PG'], 1: ['AMGN', 'HD', 'VZ'], 7: ['AXP', 'INTC', 'MMM'], 5: ['BA', 'MRK', 'UTX'], 2: ['CSCO', 'KO', 'V'], 3: ['CVX', 'IBM', 'WMT'], 6: ['DOW', 'TRV', 'XOM'], 0: ['JPM']}
#     Plot saved to: test\before\before_2010-09-23.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'CAT', 'DOW', 'HD', 'INTC', 'JPM'], 1: ['AXP', 'CVX', 'KO', 'MRK'], 2: ['BA', 'IBM', 'V', 'XOM'], 3: ['CSCO', 'MMM', 'PG', 'TRV', 'UTX', 'VZ', 'WMT']}
#     Plot saved to: test\before\before_2010-03-08.png
#   Processing Date: 2010-12-31
#     Optimal Clustering: {4: ['AAPL', 'CAT', 'CSCO'], 1: ['AMGN', 'HD', 'JPM'], 6: ['AXP', 'CVX', 'PG'], 2: ['BA', 'DOW', 'KO'], 0: ['IBM', 'INTC', 'MMM'], 3: ['MRK', 'V', 'XOM'], 5: ['TRV', 'UTX', 'VZ', 'WMT']}
#     Plot saved to: test\before\before_2010-12-31.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'KO', 'V'], 2: ['BA', 'HD'], 3: ['CAT', 'JPM'], 4: ['CSCO', 'CVX'], 5: ['DOW', 'PG'], 6: ['IBM', 'UTX'], 7: ['INTC', 'TRV'], 0: ['MMM', 'MRK'], 8: ['VZ', 'WMT', 'XOM']}
#     Plot saved to: test\before\before_2010-10-28.png
#
# Processing Period: During | File: output_cov_matrices2/during.parquet
#   Processing Date: 2010-09-23
#     Optimal Clustering: {2: ['AAPL', 'AXP', 'CAT', 'CSCO', 'DOW', 'HD', 'IBM', 'JPM', 'WMT'], 1: ['AMGN', 'BA', 'CVX', 'INTC', 'KO', 'MMM', 'VZ'], 0: ['MRK', 'PG', 'TRV', 'UTX', 'V', 'XOM']}
#     Plot saved to: test\during\during_2010-09-23.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {3: ['AAPL', 'BA', 'CVX', 'MMM', 'UTX'], 1: ['AMGN', 'PG', 'V'], 2: ['AXP', 'HD'], 4: ['CAT', 'INTC', 'MRK', 'TRV', 'WMT'], 0: ['CSCO', 'JPM'], 5: ['DOW', 'VZ', 'XOM'], 6: ['IBM', 'KO']}
#     Plot saved to: test\during\during_2010-08-20.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'V', 'WMT'], 1: ['AMGN', 'INTC', 'MRK'], 2: ['AXP', 'CVX', 'UTX'], 3: ['BA', 'CAT', 'CSCO', 'DOW', 'HD', 'IBM', 'PG'], 4: ['JPM', 'TRV', 'VZ'], 5: ['KO', 'MMM', 'XOM']}
#     Plot saved to: test\during\during_2010-01-27.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'CSCO', 'KO', 'V'], 2: ['AXP', 'BA', 'HD', 'IBM', 'INTC', 'JPM', 'MMM'], 0: ['CAT', 'CVX'], 3: ['DOW', 'MRK', 'PG', 'TRV', 'UTX', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: test\during\during_2010-10-28.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'CSCO', 'DOW', 'HD', 'IBM', 'KO', 'MMM', 'UTX'], 3: ['AMGN', 'VZ'], 1: ['BA', 'PG'], 2: ['CAT', 'CVX', 'INTC', 'JPM', 'MRK', 'TRV', 'V', 'WMT', 'XOM']}
#     Plot saved to: test\during\during_2010-06-11.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'BA', 'CAT', 'CSCO', 'CVX', 'DOW', 'HD', 'INTC', 'MMM'], 1: ['AXP', 'TRV'], 2: ['IBM', 'MRK', 'PG', 'V', 'WMT', 'XOM'], 4: ['JPM', 'UTX'], 0: ['KO', 'VZ']}
#     Plot saved to: test\during\during_2010-04-05.png
#   Processing Date: 2010-12-31
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'INTC', 'JPM', 'KO', 'MMM', 'MRK', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM'], 0: ['CSCO', 'DOW', 'HD', 'IBM']}
#     Plot saved to: test\during\during_2010-12-31.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'CAT', 'DOW', 'KO', 'MMM', 'TRV', 'V', 'WMT'], 0: ['AXP', 'BA', 'CSCO', 'CVX', 'IBM', 'INTC', 'JPM', 'MRK', 'PG', 'UTX'], 2: ['HD', 'VZ', 'XOM']}
#     Plot saved to: test\during\during_2010-07-23.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'CAT', 'CSCO', 'CVX', 'IBM', 'MMM', 'TRV'], 2: ['AXP', 'BA', 'INTC', 'MRK', 'UTX', 'V', 'WMT', 'XOM'], 4: ['DOW', 'HD'], 3: ['JPM', 'VZ'], 0: ['KO', 'PG']}
#     Plot saved to: test\during\during_2010-02-03.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: test\during\during_2010-03-08.png
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: test\during\during_2010-11-26.png
#
# Processing Period: After | File: output_cov_matrices2/after.parquet
#   Processing Date: 2010-12-31
#     Optimal Clustering: {3: ['AAPL', 'BA', 'CAT', 'DOW', 'KO', 'MMM', 'TRV', 'VZ'], 1: ['AMGN', 'INTC', 'MRK'], 2: ['AXP', 'CSCO', 'UTX', 'V', 'WMT', 'XOM'], 4: ['CVX'], 5: ['HD', 'IBM', 'PG'], 0: ['JPM']}
#     Plot saved to: test\after\after_2010-12-31.png
#   Processing Date: 2010-02-03
#     Optimal Clustering: {0: ['AAPL', 'UTX'], 1: ['AMGN', 'AXP', 'BA', 'CVX', 'DOW', 'V'], 4: ['CAT', 'PG'], 5: ['CSCO', 'TRV'], 7: ['HD', 'IBM', 'MRK', 'WMT'], 2: ['INTC', 'XOM'], 3: ['JPM', 'VZ'], 6: ['KO', 'MMM']}
#     Plot saved to: test\after\after_2010-02-03.png
#   Processing Date: 2010-08-20
#     Optimal Clustering: {0: ['AAPL', 'CAT'], 1: ['AMGN', 'AXP', 'HD', 'UTX', 'V'], 6: ['BA', 'TRV'], 5: ['CSCO', 'XOM'], 2: ['CVX', 'IBM', 'JPM'], 4: ['DOW', 'KO', 'MRK'], 3: ['INTC', 'WMT'], 7: ['MMM', 'PG', 'VZ']}
#     Plot saved to: test\after\after_2010-08-20.png
#   Processing Date: 2010-09-23
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'CAT', 'CVX', 'HD', 'IBM', 'INTC'], 2: ['BA', 'CSCO', 'MMM', 'MRK'], 1: ['DOW', 'JPM', 'KO', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: test\after\after_2010-09-23.png
#   Processing Date: 2010-07-23
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'BA', 'CSCO', 'IBM', 'PG'], 2: ['CAT', 'DOW', 'UTX'], 3: ['CVX', 'HD', 'INTC', 'KO', 'MMM', 'MRK', 'TRV', 'XOM'], 1: ['JPM', 'VZ'], 4: ['V', 'WMT']}
#     Plot saved to: test\after\after_2010-07-23.png
#   Processing Date: 2010-10-28
#     Optimal Clustering: {2: ['AAPL', 'AMGN', 'CAT', 'CSCO', 'CVX', 'HD', 'JPM', 'KO', 'WMT', 'XOM'], 3: ['AXP', 'MMM'], 0: ['BA', 'MRK', 'PG'], 1: ['DOW', 'IBM', 'INTC', 'TRV', 'UTX', 'V', 'VZ']}
#     Plot saved to: test\after\after_2010-10-28.png
#   Processing Date: 2010-04-05
#     Optimal Clustering: {0: ['AAPL', 'AXP'], 3: ['AMGN', 'HD', 'JPM'], 5: ['BA', 'DOW'], 1: ['CAT', 'CVX', 'IBM', 'MMM', 'PG'], 2: ['CSCO', 'INTC'], 4: ['KO', 'VZ'], 6: ['MRK', 'TRV', 'V', 'WMT', 'XOM'], 7: ['UTX']}
#     Plot saved to: test\after\after_2010-04-05.png
#   Processing Date: 2010-01-27
#     Optimal Clustering: {0: ['AAPL', 'CVX', 'JPM', 'PG', 'VZ'], 1: ['AMGN', 'CAT', 'UTX'], 4: ['AXP', 'CSCO', 'INTC'], 3: ['BA', 'TRV'], 5: ['DOW', 'V', 'XOM'], 6: ['HD', 'IBM', 'MRK'], 2: ['KO', 'MMM', 'WMT']}
#     Plot saved to: test\after\after_2010-01-27.png
#   Processing Date: 2010-03-08
#     Optimal Clustering: {4: ['AAPL', 'AMGN', 'INTC', 'KO', 'PG'], 1: ['AXP', 'CVX', 'HD'], 2: ['BA', 'CAT', 'CSCO'], 3: ['DOW', 'IBM', 'MMM'], 5: ['JPM', 'VZ'], 0: ['MRK', 'TRV', 'UTX', 'V', 'WMT', 'XOM']}
#     Plot saved to: test\after\after_2010-03-08.png
#   Processing Date: 2010-11-26
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: test\after\after_2010-11-26.png
#   Processing Date: 2010-06-11
#     Optimal Clustering: {2: ['AAPL', 'AMGN', 'AXP', 'CAT', 'CVX', 'DOW', 'IBM', 'INTC', 'KO', 'MRK', 'UTX', 'XOM'], 3: ['BA', 'JPM', 'MMM', 'V', 'VZ', 'WMT'], 1: ['CSCO', 'PG'], 0: ['HD', 'TRV']}
#     Plot saved to: test\after\after_2010-06-11.png
#
# All clustering and plotting completed.
