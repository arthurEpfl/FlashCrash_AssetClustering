# %% [markdown]
# ## Librairies used :

# %%
import pandas as pd
import numpy as np
import polars as pl
import tarfile
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from typing import Tuple
import os
import itertools
from numpy import linalg as LA
import numpy as np
from numpy.linalg import eig
import networkx as nx
from sklearn.preprocessing import MinMaxScaler
import community
from matplotlib.patches import Patch
from utils_clustering import *

# %% [markdown]
# ## Compute covariance matrices

# %% [markdown]
# **Computing the covariance matrices with hayashi_yoshida estimator using the functions in utils on the dates with highest responses**

# %%
# Array of mapped strings for the highest responses per month
highest_responses_strings = np.array(['2010-01-27-14:00',
    '2010-02-03-13:00',
    '2010-03-08-12:30',
    '2010-04-05-10:00',
    '2010-06-11-13:15',
    '2010-07-23-12:45',
    '2010-08-20-12:45',
    '2010-09-23-14:30',
    '2010-10-28-13:00',
    '2010-11-26-13:15',
    '2010-12-31-12:00'
])

# Asset names
asset_names = [
    'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DOW', 'HD', 'IBM',
    'INTC', 'JPM', 'KO', 'MMM', 'MRK', 'PG', 'TRV', 'UTX', 'V', 'VZ',
    'WMT', 'XOM'
]

# Step 1: Define the mapping from assets to domains
asset_to_domain = {
    'AAPL': 'Technology', 'IBM': 'Technology', 'INTC': 'Technology', 'MSFT': 'Technology',
    'AMGN': 'Healthcare', 'JNJ': 'Healthcare', 'MMM': 'Healthcare', 'MRK': 'Healthcare',
    'PFE': 'Healthcare', 'UNH': 'Healthcare',
    'AXP': 'Finance', 'GS': 'Finance', 'JPM': 'Finance', 'TRV': 'Finance',
    'BA': 'Industrials', 'CAT': 'Industrials', 'DOW': 'Industrials', 'RTX': 'Industrials',
    'UTX': 'Industrials',
    'CSCO': 'Telecommunications', 'VZ': 'Telecommunications',
    'CVX': 'Energy', 'XOM': 'Energy',
    'HD': 'Retail',
    'KO': 'Consumer Staples', 'WBA': 'Consumer Staples',
    'MCD': 'Consumer Discretionary', 'NKE': 'Consumer Discretionary',
    'PG': 'Consumer Discretionary', 'V': 'Consumer Discretionary',
    'WMT': 'Consumer Discretionary'
}

domain_colors = {
    'Technology': '#1f77b4',
    'Healthcare': '#ff7f0e',
    'Finance': '#2ca02c',
    'Industrials': '#d62728',
    'Telecommunications': '#9467bd',
    'Energy': '#8c564b',
    'Retail': '#e377c2',
    'Consumer Staples': '#7f7f7f',
    'Consumer Discretionary': '#bcbd22'
}

# %% [markdown]
# ### Compute covariance matrix for demo

# %%
compute_covariance_matrices("data_clean",
                            ["2010-05-06-14:45"],
                            "output_cov_matrices")

# %% [markdown]
# ### Compute covariance matrix for all dates

# %%
compute_covariance_matrices("data_clean",
                            highest_responses_strings,
                            "output_cov_matrices3")
# Out:
# Processing date: 2010-01-27 with start time: 14:00
# Processing date: 2010-02-03 with start time: 13:00
# Processing date: 2010-03-08 with start time: 12:30
# Processing date: 2010-04-05 with start time: 10:00

# %% [markdown]
# ## Create and plot the different clusters for each period and each date

# %% [markdown]
# **Differents steps after creating the covariances files :**
#
# - Iterate over each file and each date
# - Read the corresponding covariance matrix
# - Clip the matrix using the eigen_value method discussed in class
# - Adjust with normalization the matrix to perform Louvain clustering
# - Save the resulting clusters

# %%
def main():
    # Define the periods and their corresponding file paths

    demo_periods_files = {
        'before': 'output_cov_matrices/before.parquet',
        'during': 'output_cov_matrices/during.parquet',
        'after': 'output_cov_matrices/after.parquet'
    }

    periods_files = {
        'before': 'output_cov_matrices2/before.parquet',
        'during': 'output_cov_matrices2/during.parquet',
        'after': 'output_cov_matrices2/after.parquet'
    }

    # Create a directory to save all plots
    output_dir = 'cluster_plots2'
    os.makedirs(output_dir, exist_ok=True)

    # Iterate over each period and its corresponding file
    for period, file_path in periods_files.items():
        print(f'\nProcessing Period: {period.capitalize()} | File: {file_path}')

        # Load all covariance matrices for the period
        try:
            cov_matrices_dict = load_and_reshape_covariance(file_path)
        except Exception as e:
            print(f'Error loading file {file_path}: {e}')
            continue

        # Iterate over each date and its covariance matrix
        for date, cov_matrix in cov_matrices_dict.items():
            print(f'  Processing Date: {date}')

            try:
                # Step 1: Apply eigenvalue clipping
                clipped_cov_matrix = eigenvalue_clipping(cov_matrix)
                # Step 2: Fill diagonal with zeros
                np.fill_diagonal(clipped_cov_matrix, 0)
                clipped_cov_matrix = np.asarray(clipped_cov_matrix)
                # Step 3: Normalize the covariance matrix
                scaler = MinMaxScaler()
                adj_matrix = scaler.fit_transform(clipped_cov_matrix)
                # Step 4: Perform Louvain clustering
                partition_optimal = perform_louvain_clustering(adj_matrix)

                clusters_optimal = {}
                for node, cluster_id in partition_optimal.items():
                    # Ensure node index is within the range of asset_names
                    if node < len(asset_names):
                        asset_name = asset_names[node]
                    else:
                        asset_name = f'Asset_{node}'  # Placeholder for undefined assets
                    clusters_optimal.setdefault(cluster_id, []).append(asset_name)

                # Output the optimal clustering results
                print(f'    Optimal Clustering: {clusters_optimal}')

                # Step 6: Process the clusters to count domains
                cluster_domains = {}
                for cluster_id, assets in clusters_optimal.items():
                    # Initialize domain count for the cluster
                    domain_count = {domain: 0 for domain in domain_colors.keys()}
                    for asset in assets:
                        domain = asset_to_domain.get(asset, 'Unknown')
                        domain_count[domain] += 1
                    cluster_domains[cluster_id] = domain_count

                # Step 7: Define the save path for the plot
                # Create a directory for the period if it doesn't exist
                period_dir = os.path.join(output_dir, period)
                os.makedirs(period_dir, exist_ok=True)

                # Define the filename based on the date
                save_filename = f'{period}_{date}.png'
                save_path = os.path.join(period_dir, save_filename)

                # Step 8: Plot and save the cluster domains
                plot_cluster_domains(
                    cluster_domains=cluster_domains,
                    clusters_optimal=clusters_optimal,
                    domain_colors=domain_colors,
                    period=period,
                    date=date,
                    save_path=save_path
                )

                print(f'    Plot saved to: {save_path}')

            except Exception as e:
                print(f'    Error processing date {date}: {e}')
                continue

    print('\nAll clustering and plotting completed.')

if __name__ == "__main__":
    main()
# Out:
# Processing Period: Before | File: output_cov_matrices2/before.parquet
#   Processing Date: 2010-11-26
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'CSCO', 'DOW', 'INTC', 'KO'], 1: ['AXP', 'IBM'], 2: ['BA', 'UTX'], 3: ['CAT', 'VZ'], 5: ['CVX', 'MRK'], 6: ['HD', 'TRV'], 7: ['JPM', 'PG', 'WMT'], 8: ['MMM', 'V'], 4: ['XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-11-26.png
#   Processing Date: 2010-01-27
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'KO'], 2: ['AMGN', 'AXP', 'BA', 'CSCO', 'PG'], 3: ['CAT', 'IBM'], 4: ['CVX', 'JPM', 'TRV'], 5: ['DOW', 'INTC'], 6: ['HD', 'MRK'], 1: ['MMM', 'V'], 7: ['UTX', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-01-27.png
#   Processing Date: 2010-04-05
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'IBM', 'XOM'], 3: ['AMGN', 'AXP', 'BA'], 2: ['CAT', 'CSCO', 'CVX', 'DOW', 'HD', 'JPM', 'KO', 'MMM', 'PG', 'TRV'], 1: ['INTC', 'MRK', 'UTX', 'V', 'VZ', 'WMT']}
#     Plot saved to: cluster_plots2\before\before_2010-04-05.png
#   Processing Date: 2010-08-20
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'TRV'], 6: ['AMGN', 'HD'], 2: ['AXP', 'BA', 'DOW', 'KO'], 3: ['CAT', 'VZ'], 4: ['CSCO', 'IBM'], 5: ['CVX', 'V'], 7: ['INTC', 'UTX'], 8: ['JPM', 'PG'], 1: ['MMM', 'MRK', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-08-20.png
#   Processing Date: 2010-02-03
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'HD'], 1: ['AMGN', 'BA', 'JPM', 'VZ'], 2: ['CAT', 'UTX', 'WMT'], 3: ['CSCO', 'IBM', 'MMM', 'V', 'XOM'], 4: ['CVX', 'KO', 'TRV'], 5: ['DOW', 'INTC'], 6: ['MRK', 'PG']}
#     Plot saved to: cluster_plots2\before\before_2010-02-03.png
#   Processing Date: 2010-06-11
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {6: ['AAPL', 'CVX'], 3: ['AMGN', 'BA', 'DOW', 'UTX'], 0: ['AXP', 'INTC'], 4: ['CAT', 'PG'], 1: ['CSCO', 'MRK'], 8: ['HD', 'V'], 9: ['IBM', 'JPM'], 5: ['KO', 'VZ'], 2: ['MMM'], 7: ['TRV', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-06-11.png
#   Processing Date: 2010-07-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'BA', 'CSCO'], 1: ['AMGN', 'CAT', 'CVX', 'HD', 'IBM', 'INTC', 'JPM', 'KO', 'MMM', 'PG', 'TRV'], 2: ['DOW', 'MRK', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-07-23.png
#   Processing Date: 2010-09-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'KO', 'VZ'], 1: ['AMGN', 'JPM', 'MMM'], 7: ['AXP', 'CVX', 'PG'], 6: ['BA', 'DOW', 'XOM'], 2: ['CAT', 'UTX', 'V'], 5: ['CSCO', 'HD', 'MRK'], 4: ['IBM'], 3: ['INTC', 'TRV', 'WMT']}
#     Plot saved to: cluster_plots2\before\before_2010-09-23.png
#   Processing Date: 2010-03-08
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'CAT', 'DOW', 'HD', 'INTC', 'JPM'], 2: ['AXP', 'BA', 'CVX', 'KO', 'MRK', 'TRV', 'UTX'], 1: ['CSCO', 'IBM', 'MMM', 'PG', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-03-08.png
#   Processing Date: 2010-12-31
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {3: ['AAPL', 'DOW', 'KO'], 0: ['AMGN', 'BA', 'IBM'], 2: ['AXP', 'HD', 'UTX'], 5: ['CAT', 'V', 'XOM'], 6: ['CSCO', 'TRV', 'VZ', 'WMT'], 4: ['CVX', 'INTC', 'PG'], 1: ['JPM', 'MMM', 'MRK']}
#     Plot saved to: cluster_plots2\before\before_2010-12-31.png
#   Processing Date: 2010-10-28
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'MMM'], 6: ['AMGN', 'BA', 'HD', 'MRK', 'V'], 2: ['AXP', 'IBM'], 3: ['CAT', 'UTX'], 4: ['CSCO', 'DOW'], 5: ['CVX', 'INTC'], 1: ['JPM', 'KO'], 8: ['PG', 'TRV'], 7: ['VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\before\before_2010-10-28.png
#
# Processing Period: During | File: output_cov_matrices2/during.parquet
#   Processing Date: 2010-09-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'CAT', 'CSCO', 'DOW', 'HD', 'IBM', 'JPM', 'XOM'], 1: ['AMGN', 'BA', 'CVX', 'INTC', 'KO', 'MMM', 'VZ'], 2: ['MRK', 'PG', 'TRV', 'UTX', 'V', 'WMT']}
#     Plot saved to: cluster_plots2\during\during_2010-09-23.png
#   Processing Date: 2010-08-20
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {4: ['AAPL', 'CSCO', 'CVX', 'MMM', 'PG'], 1: ['AMGN', 'BA', 'TRV'], 0: ['AXP', 'HD'], 3: ['CAT', 'WMT'], 5: ['DOW', 'V', 'VZ'], 6: ['IBM', 'MRK'], 7: ['INTC', 'UTX'], 2: ['JPM', 'KO', 'XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-08-20.png
#   Processing Date: 2010-01-27
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'CSCO', 'UTX'], 5: ['AMGN', 'INTC', 'MMM'], 2: ['AXP', 'CAT', 'TRV'], 3: ['BA', 'KO', 'VZ'], 4: ['CVX', 'DOW', 'IBM', 'PG'], 6: ['HD', 'MRK', 'XOM'], 1: ['JPM', 'V', 'WMT']}
#     Plot saved to: cluster_plots2\during\during_2010-01-27.png
#   Processing Date: 2010-10-28
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'KO', 'V'], 3: ['CSCO', 'DOW', 'INTC', 'MMM', 'UTX'], 1: ['HD', 'JPM'], 2: ['IBM', 'MRK', 'PG', 'TRV', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-10-28.png
#   Processing Date: 2010-06-11
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AXP', 'CSCO', 'DOW', 'HD', 'IBM', 'KO', 'MMM', 'UTX'], 1: ['AMGN', 'PG'], 2: ['BA', 'CAT', 'CVX', 'INTC', 'JPM', 'MRK', 'TRV', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-06-11.png
#   Processing Date: 2010-04-05
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'BA', 'CSCO', 'CVX', 'DOW', 'HD', 'INTC', 'KO', 'MMM'], 2: ['AXP', 'VZ'], 4: ['CAT', 'PG'], 1: ['IBM', 'MRK', 'UTX', 'V', 'WMT', 'XOM'], 0: ['JPM', 'TRV']}
#     Plot saved to: cluster_plots2\during\during_2010-04-05.png
#   Processing Date: 2010-12-31
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {1: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'INTC', 'JPM', 'KO', 'MMM', 'MRK', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM'], 0: ['CSCO', 'DOW', 'HD', 'IBM']}
#     Plot saved to: cluster_plots2\during\during_2010-12-31.png
#   Processing Date: 2010-07-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {2: ['AAPL', 'AMGN', 'CAT', 'DOW', 'KO', 'MMM', 'TRV', 'V', 'WMT'], 0: ['AXP', 'BA', 'CSCO', 'CVX', 'IBM', 'INTC', 'JPM', 'MRK', 'PG', 'UTX'], 1: ['HD', 'VZ', 'XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-07-23.png
#   Processing Date: 2010-02-03
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'BA', 'HD', 'MRK', 'UTX', 'V', 'WMT', 'XOM'], 1: ['AMGN', 'CSCO', 'DOW', 'MMM', 'TRV', 'VZ'], 2: ['AXP', 'IBM'], 3: ['CAT', 'INTC'], 5: ['CVX', 'JPM'], 4: ['KO', 'PG']}
#     Plot saved to: cluster_plots2\during\during_2010-02-03.png
#   Processing Date: 2010-03-08
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-03-08.png
#   Processing Date: 2010-11-26
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots2\during\during_2010-11-26.png
#
# Processing Period: After | File: output_cov_matrices2/after.parquet
#   Processing Date: 2010-12-31
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'MRK', 'TRV'], 1: ['AMGN', 'HD', 'INTC'], 3: ['AXP', 'BA', 'CAT', 'DOW', 'IBM', 'VZ'], 4: ['CSCO', 'KO', 'PG'], 5: ['CVX', 'MMM', 'UTX', 'V', 'WMT', 'XOM'], 2: ['JPM']}
#     Plot saved to: cluster_plots2\after\after_2010-12-31.png
#   Processing Date: 2010-02-03
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {3: ['AAPL', 'UTX'], 1: ['AMGN', 'TRV'], 2: ['AXP', 'BA', 'DOW', 'V'], 4: ['CAT', 'KO'], 5: ['CSCO', 'INTC'], 6: ['CVX', 'WMT'], 7: ['HD', 'IBM', 'MRK', 'PG'], 8: ['JPM', 'VZ'], 0: ['MMM', 'XOM']}
#     Plot saved to: cluster_plots2\after\after_2010-02-03.png
#   Processing Date: 2010-08-20
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'VZ'], 1: ['AMGN', 'AXP', 'HD', 'TRV', 'V'], 2: ['BA', 'INTC'], 4: ['CAT', 'PG'], 6: ['CSCO', 'CVX', 'JPM'], 7: ['DOW', 'KO', 'UTX'], 5: ['IBM', 'MMM', 'XOM'], 3: ['MRK', 'WMT']}
#     Plot saved to: cluster_plots2\after\after_2010-08-20.png
#   Processing Date: 2010-09-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'AMGN', 'AXP', 'CAT', 'CVX', 'HD', 'IBM', 'INTC', 'MMM'], 2: ['BA', 'CSCO', 'JPM', 'MRK'], 1: ['DOW', 'KO', 'PG', 'TRV', 'UTX', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\after\after_2010-09-23.png
#   Processing Date: 2010-07-23
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'CAT', 'CVX', 'DOW', 'INTC', 'MMM', 'TRV', 'XOM'], 3: ['AMGN', 'BA', 'HD', 'IBM', 'JPM', 'KO', 'V'], 2: ['AXP', 'WMT'], 1: ['CSCO', 'VZ'], 4: ['MRK', 'PG', 'UTX']}
#     Plot saved to: cluster_plots2\after\after_2010-07-23.png
#   Processing Date: 2010-10-28
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'CAT', 'CSCO', 'CVX', 'HD', 'JPM', 'KO', 'WMT', 'XOM'], 1: ['AXP', 'MMM'], 2: ['BA', 'MRK', 'PG'], 0: ['DOW', 'IBM', 'INTC', 'TRV', 'UTX', 'V', 'VZ']}
#     Plot saved to: cluster_plots2\after\after_2010-10-28.png
#   Processing Date: 2010-04-05
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {5: ['AAPL', 'KO'], 1: ['AMGN', 'CSCO', 'CVX', 'IBM', 'PG'], 4: ['AXP', 'VZ'], 0: ['BA', 'DOW'], 3: ['CAT', 'HD'], 2: ['INTC', 'JPM', 'MMM'], 7: ['MRK', 'TRV', 'UTX', 'WMT', 'XOM'], 6: ['V']}
#     Plot saved to: cluster_plots2\after\after_2010-04-05.png
#   Processing Date: 2010-01-27
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'IBM', 'UTX'], 1: ['AMGN', 'BA', 'CSCO', 'CVX', 'PG'], 2: ['AXP', 'CAT', 'INTC'], 4: ['DOW', 'MRK', 'V'], 3: ['HD', 'TRV'], 6: ['JPM', 'MMM', 'VZ'], 5: ['KO', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\after\after_2010-01-27.png
#   Processing Date: 2010-03-08
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL', 'CAT', 'INTC', 'KO', 'PG'], 4: ['AMGN', 'HD', 'JPM'], 2: ['AXP', 'BA', 'CSCO'], 3: ['CVX', 'DOW', 'IBM'], 5: ['MMM', 'UTX'], 1: ['MRK', 'TRV', 'V', 'VZ', 'WMT', 'XOM']}
#     Plot saved to: cluster_plots2\after\after_2010-03-08.png
#   Processing Date: 2010-11-26
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {0: ['AAPL'], 1: ['AMGN'], 2: ['AXP'], 3: ['BA'], 4: ['CAT'], 5: ['CSCO'], 6: ['CVX'], 7: ['DOW'], 8: ['HD'], 9: ['IBM'], 10: ['INTC'], 11: ['JPM'], 12: ['KO'], 13: ['MMM'], 14: ['MRK'], 15: ['PG'], 16: ['TRV'], 17: ['UTX'], 18: ['V'], 19: ['VZ'], 20: ['WMT'], 21: ['XOM']}
#     Plot saved to: cluster_plots2\after\after_2010-11-26.png
#   Processing Date: 2010-06-11
# 0
# 1
# 2
# 3
# 4
#     Optimal Clustering: {3: ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'DOW', 'INTC', 'MRK', 'TRV', 'UTX', 'XOM'], 1: ['CSCO', 'JPM', 'MMM', 'V', 'VZ', 'WMT'], 2: ['HD', 'PG'], 0: ['IBM', 'KO']}
#     Plot saved to: cluster_plots2\after\after_2010-06-11.png
#
# All clustering and plotting completed.

# %%
def main(demo=True):
    # Define the periods and their corresponding file paths
    demo_periods_files = {
        'before': 'output_cov_matrices/before.parquet',
        'during': 'output_cov_matrices/during.parquet',
        'after': 'output_cov_matrices/after.parquet'
    }

    periods_files = {
        'before': 'output_cov_matrices2/before.parquet',
        'during': 'output_cov_matrices2/during.parquet',
        'after': 'output_cov_matrices2/after.parquet'
    }

    # Select the appropriate file paths based on the demo flag
    selected_files = demo_periods_files if demo else periods_files

    # Create a directory to save all plots
    output_dir = 'cluster_plots2'
    os.makedirs(output_dir, exist_ok=True)

    # Iterate over each period and its corresponding file
    for period, file_path in selected_files.items():
        print(f'\nProcessing Period: {period.capitalize()} | File: {file_path}')

        # Load all covariance matrices for the period
        try:
            cov_matrices_dict = load_and_reshape_covariance(file_path)
        except Exception as e:
            print(f'Error loading file {file_path}: {e}')
            continue

        # Iterate over each date and its covariance matrix
        for date, cov_matrix in cov_matrices_dict.items():
            print(f'  Processing Date: {date}')

            try:
                # Step 1: Apply eigenvalue clipping
                clipped_cov_matrix = eigenvalue_clipping(cov_matrix)
                # Step 2: Fill diagonal with zeros
                np.fill_diagonal(clipped_cov_matrix, 0)
                clipped_cov_matrix = np.asarray(clipped_cov_matrix)
                # Step 3: Normalize the covariance matrix
                scaler = MinMaxScaler()
                adj_matrix = scaler.fit_transform(clipped_cov_matrix)
                # Step 4: Perform Louvain clustering
                partition_optimal = perform_louvain_clustering(adj_matrix)

                clusters_optimal = {}
                for node, cluster_id in partition_optimal.items():
                    # Ensure node index is within the range of asset_names
                    if node < len(asset_names):
                        asset_name = asset_names[node]
                    else:
                        asset_name = f'Asset_{node}'  # Placeholder for undefined assets
                    clusters_optimal.setdefault(cluster_id, []).append(asset_name)

                # Output the optimal clustering results
                print(f'    Optimal Clustering: {clusters_optimal}')

                # Step 6: Process the clusters to count domains
                cluster_domains = {}
                for cluster_id, assets in clusters_optimal.items():
                    # Initialize domain count for the cluster
                    domain_count = {domain: 0 for domain in domain_colors.keys()}
                    for asset in assets:
                        domain = asset_to_domain.get(asset, 'Unknown')
                        domain_count[domain] += 1
                    cluster_domains[cluster_id] = domain_count

                # Step 7: Define the save path for the plot
                # Create a directory for the period if it doesn't exist
                period_dir = os.path.join(output_dir, period)
                os.makedirs(period_dir, exist_ok=True)

                # Define the filename based on the date
                save_filename = f'{period}_{date}.png'
                save_path = os.path.join(period_dir, save_filename)

                # Step 8: Plot and save the cluster domains
                plot_cluster_domains(
                    cluster_domains=cluster_domains,
                    clusters_optimal=clusters_optimal,
                    domain_colors=domain_colors,
                    period=period,
                    date=date,
                    save_path=save_path
                )

                print(f'    Plot saved to: {save_path}')

            except Exception as e:
                print(f'    Error processing date {date}: {e}')
                continue

    print('\nAll clustering and plotting completed.')

if __name__ == "__main__":
    main(demo=True)  # Change demo=True or demo=False as needed
